# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://edae08c77e11:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# %%sql
# show databases
# Out:
# 24/10/13 10:47:58 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# +-----------+
# | namespace |
# +-----------+
# |   default |
# |       nyc |
# +-----------+

# %%
# %%sql
# show tables in default
# Out:
# +-----------+-----------+-------------+
# | namespace | tableName | isTemporary |
# +-----------+-----------+-------------+
# +-----------+-----------+-------------+

# %%
# %%sql
# DROP TABLE default.my_first_dbt_model
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# DESCRIBE FORMATTED default.my_first_dbt_model
# Out:
# +------------------------------+------------------------------------------------------------+---------+
# |                     col_name |                                                  data_type | comment |
# +------------------------------+------------------------------------------------------------+---------+
# |                           id |                                                        int |    None |
# |                              |                                                            |         |
# | # Detailed Table Information |                                                            |         |
# |                      Catalog |                                              spark_catalog |         |
# |                     Database |                                                    default |         |
# |                        Table |                                         my_first_dbt_model |         |
# ...

# %%
# %%sql
# DESCRIBE FORMATTED default.my_first_dbt_model
# Out:
# +------------------------------+------------------------------------------------------------------------------------------------------------------------+---------+
# |                     col_name |                                                                                                              data_type | comment |
# +------------------------------+------------------------------------------------------------------------------------------------------------------------+---------+
# |                           id |                                                                                                                    int |    None |
# |                              |                                                                                                                        |         |
# |           # Metadata Columns |                                                                                                                        |         |
# ...

# %%
# %%sql
# select * from default.my_first_dbt_model
# Out:
# 24/10/13 10:58:02 WARN SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.
# +------+
# |   id |
# +------+
# |    1 |
# | None |
# +------+

# %%
# %%sql
# DROP TABLE default.my_first_dbt_model PURGE
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("drop table default.my_first_dbt_model")
# Out:
# DataFrame[]

# %%
# %%sql
# DROP TABLE my_second_dbt_model
# Out:
# ++
# ||
# ++
# ++
